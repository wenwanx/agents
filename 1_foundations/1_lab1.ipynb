# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.12)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.12)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.

# %%
# First let's do an import. If you get an Import Error, see Q5 and then Q25 here: https://edwarddonner.com/avatar

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# False

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file might have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key not set - please head to the troubleshooting guide in the setup folder

# %%
# And now - the all important import statement
# If you get an import error - head over to Q5 and Q25 in the FAQ at https://edwarddonner.com/avatar
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "Tell me a fun fact"}]

# %%
messages
# Out:
# [{'role': 'user', 'content': 'Tell me a fun fact'}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 5.4 nano, an incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(model="llama3.2", messages=messages)
print(response.choices[0].message.content)
# Out:
# Here's a fun fact:
#
# There is a species of jellyfish that is immortal. The Turritopsis dohrnii, also known as the "immortal jellyfish," can transform its body into a younger state through a process called transdifferentiation. This means it can essentially revert back to its polyp stage and grow back into an adult again, making it theoretically immortal!

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 5.4 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(model="llama3.2", messages=messages)
question = response.choices[0].message.content
print(question)
# Out:
# What is the fundamental difference between the set of all natural numbers and the set of all integers, given that both sets can be put into a one-to-one correspondence between certain regular polygonal coordinates?

# %%
# form a new messages list

messages = [{"role": "user", "content": question}]
messages
# Out:
# [{'role': 'user',
#   'content': 'What is the fundamental difference between the set of all natural numbers and the set of all integers, given that both sets can be put into a one-to-one correspondence between certain regular polygonal coordinates?'}]

# %%
# Ask the model to answer the hard question

response = openai.chat.completions.create(model="llama3.2", messages=messages)
answer = response.choices[0].message.content
print(answer)
# Out:
# The fundamental difference between the set of all natural numbers (also known as the positive integers) and the set of all integers lies in their definitions, not in their properties regarding polygonal coordinates.
#
# * The set of all natural numbers consists of all non-negative integers: 0, 1, 2, 3, ...
# * The set of all integers includes all negative integers, zeros, and positive integers: ..., -3, -2, -1, 0, 1, 2, 3, ...
#
# In other words, the integer set is not limited to just non-negative numbers like the natural number set. This difference has implications for various mathematical structures, such as algebraic properties, divisibility rules, and many others.
#
# Regarding one-to-one correspondence with regular polygonal coordinates:
#
# Both sets can be put into a one-to-one correspondence with certain regular polygonal coordinates using combinatorial or topological arguments (e.g., Cartesian products of polygon coordinates).
#
# However, the specific choice of coordinates depends on the mathematical property being explored. For example:
#
# * The natural number set has a simple discrete structure that lends itself to one-to-one correspondence with coordinates representing "number-of-vertices" configurations.
# * The integer set has a more complex structure due to its inclusion of negative numbers and zeros.
#
# In summary, while there can be a one-to-one correspondence between these sets using specific regular polygonal coordinates, the distinction lies in their foundational definitions and properties.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# The fundamental difference between the set of all natural numbers (also known as the positive integers) and the set of all integers lies in their definitions, not in their properties regarding polygonal coordinates.
#
# * The set of all natural numbers consists of all non-negative integers: 0, 1, 2, 3, ...
# * The set of all integers includes all negative integers, zeros, and positive integers: ..., -3, -2, -1, 0, 1, 2, 3, ...
#
# In other words, the integer set is not limited to just non-negative numbers like the natural number set. This difference has implications for various mathematical structures, such as algebraic properties, divisibility rules, and many others.
#
# Regarding one-to-one correspondence with regular polygonal coordinates:
#
# Both sets can be put into a one-to-one correspondence with certain regular polygonal coordinates using combinatorial or topological arguments (e.g., Cartesian products of polygon coordinates).
#
# However, the specific choice of coordinates depends on the mathematical property being explored. For example:
#
# * The natural number set has a simple discrete structure that lends itself to one-to-one correspondence with coordinates representing "number-of-vertices" configurations.
# * The integer set has a more complex structure due to its inclusion of negative numbers and zeros.
#
# In summary, while there can be a one-to-one correspondence between these sets using specific regular polygonal coordinates, the distinction lies in their foundational definitions and properties.

# %%
message = f"""
Here is a question:
{question}

And here is a possible answer that might be correct or incorrect:
{answer}

Please evaluate if the answer is correct or incorrect.
"""

print(message)
# Out:
# Here is a question:
# What is the fundamental difference between the set of all natural numbers and the set of all integers, given that both sets can be put into a one-to-one correspondence between certain regular polygonal coordinates?
#
# And here is a possible answer that might be correct or incorrect:
# The fundamental difference between the set of all natural numbers (also known as the positive integers) and the set of all integers lies in their definitions, not in their properties regarding polygonal coordinates.
#
# * The set of all natural numbers consists of all non-negative integers: 0, 1, 2, 3, ...
# * The set of all integers includes all negative integers, zeros, and positive integers: ..., -3, -2, -1, 0, 1, 2, 3, ...
#
# In other words, the integer set is not limited to just non-negative numbers like the natural number set. This difference has implications for various mathematical structures, such as algebraic properties, divisibility rules, and many others.
#
# Regarding one-to-one correspondence with regular polygonal coordinates:
#
# Both sets can be put into a one-to-one correspondence with certain regular polygonal coordinates using combinatorial or topological arguments (e.g., Cartesian products of polygon coordinates).
#
# However, the specific choice of coordinates depends on the mathematical property being explored. For example:
#
# * The natural number set has a simple discrete structure that lends itself to one-to-one correspondence with coordinates representing "number-of-vertices" configurations.
# * The integer set has a more complex structure due to its inclusion of negative numbers and zeros.
#
# In summary, while there can be a one-to-one correspondence between these sets using specific regular polygonal coordinates, the distinction lies in their foundational definitions and properties.
#
# Please evaluate if the answer is correct or incorrect.

# %%
messages = [{"role": "user", "content": message}]
response = openai.chat.completions.create(model="llama3.2", messages=messages)
print(response.choices[0].message.content)
# Out:
# The answer is CORRECT.
#
# The fundamental difference between the set of all natural numbers and the set of all integers lies indeed in their definitions. The set of natural numbers consists of non-negative integers (0, 1, 2, 3, ...), while the set of integers includes negative integers, zero, and positive integers.
#
# This distinction has significant implications for various mathematical structures, such as algebraic properties, divisibility rules, and many others.
#
# Regarding one-to-one correspondence with regular polygonal coordinates, the answer correctly points out that both sets can be matched using suitable coordinates, but the specific choice of coordinates depends on the underlying mathematical property being explored. The natural number set's simple discrete structure lends itself to one-to-one correspondence with "number-of-vertices" configurations, while the integer set's more complex structure is due to its inclusion of negative numbers and zeros.
#
# Overall, the answer provides a clear explanation of the distinction between the two sets and their respective properties in relation to regular polygonal coordinates.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Pick a business area that might be worth exploring for an Agentic AI opportunity. Only respond the name of the area."}]

# Then make the first call:

response = openai.chat.completions.create(model="llama3.2", messages=messages)
print(response.choices[0].message.content)

# Then read the business idea:

business_area = response.choices[0].message.content

# And repeat! In the next message, include the business area within the message
# Out:
# Cybersecurity

# %%
# Ask pain point this time: 
# Create new messages
message = f"""Present a pain point in {business_area}  - something challenging that might be ripe for an Agentic solution. Only respond the pain point itself. """
print(message)
messages = [{"role": "user", "content": message}]

# Then make the second call:

response = openai.chat.completions.create(model="llama3.2", messages=messages)
pain_point = response.choices[0].message.content
print(pain_point)
# Out:
# Present a pain point in Cybersecurity  - something challenging that might be ripe for an Agentic solution. Only respond the pain point itself.
# Current Incident Response Playbooks are Not Scalable and Reusable Across Business Units and Organizations of All Sizes, Leading to Inefficient Handovers and Increased Risk of Repeating Vulnerabilities in Rapidly Evolving Attacks.

# %%
# Finally the proposal: 
# Create new messages
message = f"""With this following pain point on {business_area}, propose a Agentic AI solution: 
{pain_point}"""
messages = [{"role": "user", "content": message}]

# Then make the second call:

response = openai.chat.completions.create(model="llama3.2", messages=messages)
proposal = response.choices[0].message.content

from IPython.display import Markdown, display
display(Markdown(proposal))
# Out:
# Proposed Solution: Autonomous Threat Response Engine (ATRE)
#
#  Overview:
#
# The Autonomous Threat Response Engine (ATRE) is an agentic AI-powered solution that addresses the pain point of inefficiencies in incident response playbooks across different business units and organizations of varying sizes. ATRE's machine learning capabilities enable self-explanatory and context-driven responses, optimizing efficiency and reducing risk.
#
#  Key Features:
#
# 1. **Playbook Automation**: Modular and modular-based architecture integrating various playbooks specific to each industry/organization, thereby minimizing redundant security protocols.
# 2. **Threat Pattern Identification**: Sophisticated Natural Language Processing (NLP) analysis integrates threat patterns into the AI's knowledge graph for advanced decision support.
# 3. **Self-learning Capabilities**: The AI leverages its past experiences in processing and executing attacks to improve responses according to an evolving scenario of threats.
# 4. **Automated Communication Integration**: Smart integration with multiple communication platforms including email automation, alert systems, and messaging to promptly coordinate incident responses with teams globally.
# 5. **Risk Management and Compliance Tracking**: ATRE continuously assesses scenarios against established regulations (e.g., GDPR, HIPAA) with AI-driven analytics reporting for continuous monitoring and improvement.
#
#  Functionality:
#
# 1. **Threat Detection**: Integrated network intrusion detection tools monitor for external threats to detect and classify them rapidly into priority.
# 2. **Incident Response Actions Plan (IRAP)**: Based on threat detection AI takes a predetermined sequence of actions, using both playbooks and risk assessments.
# 3. **Data Analysis with Analytics Tools**: Utilizes automated data integration techniques for real-time insights during responses.
# 4. **User Assistance**: A comprehensive interface for manual oversight where users can input custom rules or updates into the process via customizable dashboards.
#
#  Advantages:
#
# 1. Reduced Re-activation of Vulnerabilities: AI proactively detects similar attack patterns and takes preventive measures through early incident activation.
# 2. Optimized Communication Flow: Seamless communication is facilitated between organizations with a standardized interface for reporting, which reduces unnecessary confusion during incidents.
# 3. Personalized Protection Strategies: Customized response modules enable adaptive security for any unit based on its industry or sector-specific threat profile.
#
#  Limitations and Considerations:
#
# 1. **Integration**: Complete compatibility across various software platforms to fully leverage the capabilities of ATRE would require a single solution integration vendor.
# 2. **Customization Limitation & Compliance**: Due to its AI-driven nature, full regulatory compliance is ensured by ongoing assessment against evolving standards. However, each customization must still operate under these rules for legitimacy.
#
# In conclusion, autonomous threat response engines like ATRE are poised to bridge the gap in efficiency and resilience amidst growing threats while providing highly personalized protection plans according to organizational dynamics.
